# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15, 15))

# %%
plt.hist(df['Ticket'] , bins = 20 , color = 'skyblue' , edgecolor='black')
# Out:
# (array([61., 63., 54., 46., 54., 41., 50., 51., 49., 44., 42., 39., 37.,
#         38., 40., 36., 39., 36., 36., 35.]),
#  array([  0.,  34.,  68., 102., 136., 170., 204., 238., 272., 306., 340.,
#         374., 408., 442., 476., 510., 544., 578., 612., 646., 680.]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['Ticket'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Ticket Prices')
plt.xlabel('Ticket Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import seaborn as sns

# %% [raw]
# import matplotlib.pyplot

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize = (10 ,6))

# %%
sns.boxplot(data = df, x='Ticket', color='skyblue')
# Out:
# <Axes: xlabel='Ticket'>

# %%
plt.title('Distribution of Ticket Prices')
plt.xlabel('Ticket Price')
plt.show()

# %%
sns.boxplot(data = df, x='Ticket', color='skyblue')
plt.title('Distribution of Ticket Prices')
plt.xlabel('Ticket Price')
plt.show()

# %%
df['Ticket'].hist()
# Out:
# <Axes: >

# %%
data = df

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Fare'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Ticket Fare')
plt.ylabel('Frequency')
plt.title('Ticket Fare Distribution')
plt.show()

# %%
df['Sex'].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(x='Age' , y='Sex' , hue='Survived',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>
